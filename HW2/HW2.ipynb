# %% [markdown]
# ## Data Science Principles with Applications on Educational Data, Spring 2024
# ## HW2
# ### Due date: 05/13/2024
#
# ### Student ID: 112598082
# ### Name: 陳維鈞
#
# This homework set is to practice some common visualization operations with **seaborn**. Like HW1, we use the famous **iris** data set as an example for your reference. Please load the working dataset "udemy_courses" provided with .csv format and go through each question.
#
# ### Visualize the data with  **seaborn**
# ### use **udemy_courses.csv** as the dataset and answer each part
#
# #### Illustration for writng the HW
# Example: print(iris.head())
#
# Answer : print(udemy.head())

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

iris = sns.load_dataset('iris')
# Load the dataset from the file path 
udemy = pd.read_csv('udemy_courses.csv')
udemy.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %% [markdown]
# ### 1. Select the column and plot a bar chart
#
# - `sns.countplot("col1", data = df)`
#
# Try to select the column `level` in udemy dataset

# %%
# Example
sns.countplot(x="species", data=iris)
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
# Write Answer here
sns.countplot(x='level', data=udemy)
# Out:
# <Axes: xlabel='level', ylabel='count'>

# %% [markdown]
# ### 2. Combining results
# - `df.groupby(['column_names'])` groups the data by the specified columns.
#
# - The `.size()` function then counts the number of occurrences for each group.
#
# - `reset_index(name='count')` transforms the result into a DataFrame and names the count column as 'count'.
#
# Try to groupby `level` and `is_paid` in udemy dataset and reset_index name by `count`

# %%
# Example
species_petal_width = iris.groupby(['petal_width', 'species']).size().reset_index(name='count')
species_petal_width = species_petal_width.sort_values(by='petal_width', ascending=False)
species_petal_width
# Out:
#     petal_width     species  count
# 26          2.5   virginica      3
# 25          2.4   virginica      3
# 24          2.3   virginica      8
# 23          2.2   virginica      3
# 22          2.1   virginica      6
# 21          2.0   virginica      6
# 20          1.9   virginica      5
# 19          1.8   virginica     11
# 18          1.8  versicolor      1
# 17          1.7   virginica      1
# 16          1.7  versicolor      1
# 14          1.6  versicolor      3
# 15          1.6   virginica      1
# 13          1.5   virginica      2
# 12          1.5  versicolor     10
# 11          1.4   virginica      1
# 10          1.4  versicolor      7
# 9           1.3  versicolor     13
# 8           1.2  versicolor      5
# 7           1.1  versicolor      3
# 6           1.0  versicolor      7
# 5           0.6      setosa      1
# 4           0.5      setosa      1
# 3           0.4      setosa      7
# 2           0.3      setosa      7
# 1           0.2      setosa     29
# ...

# %%
sns.barplot(x='petal_width', y='count', hue='species', data=species_petal_width)
plt.show()

# %% [markdown]
# Try to groupby `level` and `is_paid` in udemy dataset and reset_index name by `count`

# %%
# Write Answer here
is_paid_count = udemy.groupby(['level', 'is_paid']).size().reset_index(name='count')
is_paid_count = is_paid_count.sort_values(by='level', ascending=False)
is_paid_count
# Out:
#                 level  is_paid  count
# 5  Intermediate Level    False     30
# 6  Intermediate Level     True    391
# 4        Expert Level     True     58
# 2      Beginner Level    False    158
# 3      Beginner Level     True   1112
# 0          All Levels    False    122
# 1          All Levels     True   1807

# %%
sns.barplot(x='is_paid', y='count', hue='level', data=is_paid_count)
plt.show()

# %% [markdown]
# ### 3. Scatterplot
#
#  - sns.scatterplot(data=df, x="col1", y="col2", hue="subject")
#
# Visualize the distributions  of   `num_subscribers` and `num_reviews` with `subject`

# %%
# Example
sns.scatterplot(data=iris, x='sepal_length', y='petal_length', hue='species')
plt.show()

# %%
# Write Answer here
sns.scatterplot(data=udemy, x='num_subscribers', y='num_reviews', hue='subject')
plt.show()

# %% [markdown]
# ### 4. Select the following column to plot the seaborn pairplot
# - `price`
# - `num_subscribers`
# - `num_reviews`
# - `num_lectures`
# - `content_duration`
# - `subject`
#
# hue use `subject`
#
# - sns.pairplot(data=df, hue="subject")

# %%
# Example
sns.pairplot(data=iris[['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']], hue="species")
plt.show()

# %%
# Write Answer here
sns.pairplot(data=udemy[['price', 'num_subscribers', 'num_reviews', 'num_lectures', 'content_duration', 'subject']], hue='subject')
plt.show()
